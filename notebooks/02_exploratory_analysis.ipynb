# %% [markdown]
# # Notebook 02: Exploratory Data Analysis (EDA)
#
# **Project:** Crime Data Mining University Project
# **Objective:** Explore the cleaned dataset, analyze demographic/temporal/geospatial patterns of crimes, and perform descriptive statistical checks to generate hypothesis for modeling.
#
# ---

# %% [markdown]
# ## 1. Environment Setup
# Import essential libraries and the processed dataset.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Settings for visualization style
plt.style.use('ggplot')
sns.set_theme(style="whitegrid")

PROCESSED_DATA_DIR = '../data/processed'
print("Environment initialized for EDA.")

# %% [markdown]
# ## 2. Load Processed Dataset
# Load the cleaned crime dataset.

# %%
# df = pd.read_csv(os.path.join(PROCESSED_DATA_DIR, 'cleaned_crime_data.csv'))
# print(df.head())

# %% [markdown]
# ## 3. Univariate Analysis
# Investigate distributions of single variables:
# - Frequency of crime types (bar plots).
# - Crime counts over time (hourly, daily, monthly, yearly trends).
# - Spatial distribution (crime hot spots by zone/neighborhood).

# %%
# df['crime_type'].value_counts().plot(kind='bar')
# plt.title('Distribution of Crime Types')
# plt.show()

# %% [markdown]
# ## 4. Bivariate & Multivariate Analysis
# Explore correlations and relationships between variables:
# - Crime type vs Time of day (heatmap).
# - Arrest rate vs Crime type (stacked bar charts).
# - Temporal patterns grouped by Year-over-Year.

# %%
# cross_tab = pd.crosstab(df['hour'], df['crime_type'])
# sns.heatmap(cross_tab, cmap='YlGnBu')
# plt.title('Heatmap: Crime Type by Hour of Day')
# plt.show()

# %% [markdown]
# ## 5. Summary of EDA Findings
# Write down key takeaways here (e.g., peak crime times, top zones, patterns in weapon usage) to guide the modeling or report writing stage.
