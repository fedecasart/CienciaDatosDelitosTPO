# %% [markdown]
# # Notebook 01: Data Ingestion & Cleaning
#
# **Project:** Crime Data Mining University Project
# **Objective:** Ingest raw crime-related datasets, perform initial diagnostics, clean and structure the data, and export the processed datasets for analysis.
#
# ---

# %% [markdown]
# ## 1. Environment Setup & Configurations
# Import essential libraries and define project directories/settings.

# %%
import os
import sys
import pandas as pd
import numpy as np

# Add src to path if needed for custom modules
sys.path.append(os.path.abspath('../src'))
import cleaning as clean

# Configurations
RAW_DATA_DIR = '../data/raw'
PROCESSED_DATA_DIR = '../data/processed'
print("Environment initialized.")

# %% [markdown]
# ## 2. Ingest Raw Datasets
# Load data files (CSV, JSON, Excel, etc.) and perform basic verification of shape and columns.

# %%
# Example loading code (replace filenames when datasets are available)
# raw_df = pd.read_csv(os.path.join(RAW_DATA_DIR, 'crime_dataset.csv'))
# print(f"Loaded dataset with shape: {raw_df.shape}")

# %% [markdown]
# ## 3. Initial Diagnostics & Data Profiling
# - Check general info (`df.info()`).
# - Analyze data types and identify mismatching columns.
# - Inspect missing values and duplicate records.

# %%
# print(raw_df.info())
# print(raw_df.isnull().sum())

# %% [markdown]
# ## 4. Cleaning & Data Imputation
# - Handle missing values (impute, drop, or flag).
# - Remove duplicate records.
# - Format/standardize column names.
# - Standardize datetime columns, categorical string values, and geospatial markers if applicable.

# %%
# Example cleaning steps:
# clean_df = clean.remove_duplicates(raw_df)
# clean_df = clean.standardize_headers(clean_df)

# %% [markdown]
# ## 5. Export Processed Dataset
# Save the finalized, clean dataset into the `data/processed/` folder. This version will be used for all subsequent analysis notebooks.

# %%
# clean_df.to_csv(os.path.join(PROCESSED_DATA_DIR, 'cleaned_crime_data.csv'), index=False)
# print("Processed dataset successfully saved!")
