# %% [markdown]
# # Notebook 03: Final Visualizations & Figures
#
# **Project:** Crime Data Mining University Project
# **Objective:** Build polished, publication-ready visualizations and export them to `reports/figures/` for use in reports, academic papers, and presentations.
#
# ---

# %% [markdown]
# ## 1. Setup & Styling Configuration
# Import visualization tools and import custom functions from `src/visualization.py`.

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append(os.path.abspath('../src'))
import visualization as viz

# Set uniform, clean, professional plotting style for academic presentation
plt.rcParams.update({
    'font.size': 12,
    'axes.labelsize': 14,
    'axes.titlesize': 16,
    'xtick.labelsize': 11,
    'ytick.labelsize': 11,
    'figure.titlesize': 18,
    'savefig.dpi': 300, # High DPI for academic reports
    'savefig.bbox': 'tight'
})

PROCESSED_DATA_DIR = '../data/processed'
FIGURES_DIR = '../reports/figures'
print("Environment initialized for custom visual generation.")

# %% [markdown]
# ## 2. Load Processed Dataset

# %%
# df = pd.read_csv(os.path.join(PROCESSED_DATA_DIR, 'cleaned_crime_data.csv'))

# %% [markdown]
# ## 3. Generate Figure 1: Crime Temporal Trends
# Line plot of crime frequencies over months/years to illustrate macro-trends.

# %%
# Example of generating and saving a figure
# fig, ax = plt.subplots(figsize=(10, 6))
# df.groupby('month').size().plot(kind='line', ax=ax, marker='o', color='#2b5c8f', linewidth=2)
# ax.set_title('Crime Trend Over Time')
# ax.set_xlabel('Month')
# ax.set_ylabel('Incident Count')
# plt.savefig(os.path.join(FIGURES_DIR, 'fig1_temporal_trends.png'))
# plt.show()

# %% [markdown]
# ## 4. Generate Figure 2: Crime Heatmap (Hour vs Day of Week)
# Show activity hot spots based on temporal intersections.

# %%
# Example of calling custom function from src/visualization.py
# viz.plot_hourly_heatmap(df, save_path=os.path.join(FIGURES_DIR, 'fig2_hourly_heatmap.png'))

# %% [markdown]
# ## 5. Generate Figure 3: Spatial Distribution (Optional/If geospatial data available)
# Map or density plot showing high-crime coordinates.

# %%
# # Example:
# viz.plot_spatial_density(df, save_path=os.path.join(FIGURES_DIR, 'fig3_spatial_density.png'))
